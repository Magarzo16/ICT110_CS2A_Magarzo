# %% [markdown]
# #### Exercise 1

# %%
if x > 50 :
    print('Above 50')
elif x >  20 :
    print('Above 20')
elif x >  10 :
    print('Above 10')
elif x > 0 :
    print('Above 0')
else :
    print('Something else')
# Out:
# Above 50

# %% [markdown]
# #### Exercise 2

# %%
hours = int (input("Enter Hours: "))
rate = int (input("Enter Rate: "))
if hours > 40 :
  rate = 10*1.5

pay = hours*rate
print ("Pay: ", pay)
# Out:
# Enter Hours: 41
# Enter Rate: 10
# Pay:  615.0

# %% [markdown]
# ## CHALLENGE

# %%
score = int (input("Enter Score: "))
try:
  if score >= 97 and score <= 100:
    grade = 1.0
  elif score >= 93 and score < 97:
    grade = 1.25
  elif score >= 89 and score < 93:
    grade = 1.5
  elif score >= 85 and score < 89:
    grade = 1.75
  elif score >= 81 and score < 85:
    grade = 2.0
  elif score >= 77 and score < 81:
    grade = 2.25
  elif score >= 74 and score < 77:
    grade = 2.5
  elif score >= 0 and score < 74:
    grade = 3.0
  print ("Grade: ", grade)
except:
  print ("Input error! Enter scores only ranging from 0-100")
# Out:
# Enter Score: 200
# Input error! Enter scores only ranging from 0-100
