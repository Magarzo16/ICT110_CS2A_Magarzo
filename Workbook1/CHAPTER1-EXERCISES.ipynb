# %% [markdown]
# EXERCISE 1

# %%
print('Hello world!')
#the error was the letter "p" is in capital letter

# %%
print('Hello world!')
#the error is that there is a missing apostrope

# %%
print('Hello world!')
#missing open parenthesis

# %%
print('Hello world!')
#two apostrophes

# %% [markdown]
# EXERCISE 2

# %%
x = 43
x = x + 1
print(x)
44

# %% [markdown]
# EXERCISE 3

# %%
x = 43
x = x + 1
print(x)
#change "x" into small letter
